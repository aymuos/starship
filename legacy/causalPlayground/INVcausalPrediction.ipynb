# %% [markdown]
# ICP algo :
#
# ICP directly operationalizes the assumption:
#
# 𝑃(𝑌∣𝑆,𝑒)= 𝑃(𝑌∣𝑆)∀𝑒
#
# “Which subset of variables predicts ETA stably across cities/days?”

# %%
pip install causal-learn ecoml
# Out:
# Requirement already satisfied: causal-learn in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (0.1.4.3)
# Requirement already satisfied: ecoml in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (0.1.3)
# Requirement already satisfied: numpy in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (2.3.5)
# Requirement already satisfied: scipy in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (1.15.3)
# Requirement already satisfied: scikit-learn in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (1.7.2)
# Requirement already satisfied: graphviz in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (0.21)
# Requirement already satisfied: statsmodels in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (0.14.6)
# Requirement already satisfied: pandas in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (2.3.3)
# Requirement already satisfied: matplotlib in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (3.10.7)
# Requirement already satisfied: networkx in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (3.6)
# Requirement already satisfied: pydot in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (4.0.1)
# Requirement already satisfied: tqdm in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (4.67.1)
# Requirement already satisfied: momentchi2 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from causal-learn) (0.1.8)
# Requirement already satisfied: psutil in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ecoml) (7.1.3)
# Requirement already satisfied: pynvml in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ecoml) (13.0.1)
# Requirement already satisfied: GPUtil in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ecoml) (1.4.0)
# Requirement already satisfied: python-dotenv in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ecoml) (1.2.1)
# Requirement already satisfied: ipython in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ecoml) (9.8.0)
# Requirement already satisfied: decorator>=4.3.2 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ipython->ecoml) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ipython->ecoml) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ipython->ecoml) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ipython->ecoml) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ipython->ecoml) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ipython->ecoml) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ipython->ecoml) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ipython->ecoml) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from ipython->ecoml) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from matplotlib->causal-learn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from matplotlib->causal-learn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from matplotlib->causal-learn) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from matplotlib->causal-learn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from matplotlib->causal-learn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from matplotlib->causal-learn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from matplotlib->causal-learn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from matplotlib->causal-learn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from pandas->causal-learn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from pandas->causal-learn) (2025.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from pynvml->ecoml) (13.590.44)
# Requirement already satisfied: joblib>=1.2.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from scikit-learn->causal-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from scikit-learn->causal-learn) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from statsmodels->causal-learn) (1.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython->ecoml) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython->ecoml) (0.7.0)
# Requirement already satisfied: wcwidth in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ecoml) (0.2.14)
# Requirement already satisfied: six>=1.5 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->causal-learn) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->ecoml) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->ecoml) (3.0.1)
# Requirement already satisfied: pure-eval in /home/aymuos/Documents/Github/starship/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->ecoml) (0.2.3)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# - Z_raw = {
#   road_distance,
#   circuity,
#   local_turn_density,
#   rain_mm,
#   snow_present,
#   weather_regime,
#   area_speed,
#   region_speed_variance,
#   stop_index_norm,
#   active_orders,
#   shift_duration,
#   region_dwell
# }
# - Y = ETA
# - e = (city, date)

# %% [markdown]
# # invariant causal prediction

# %%
# load different city files 

import pandas as pd
import numpy as np

# Load 3 cities
cities = {
    'cq': '../LaDe/delivery/delivery_cq.csv',
    'sh': '../LaDe/delivery/delivery_sh.csv', 
    'hz': '../LaDe/delivery/delivery_hz.csv'
}

dfs = []
for city_code, filename in cities.items():
    df = pd.read_csv(filename)
    df['city_code'] = city_code  # Add if not already present
    dfs.append(df)

df_all = pd.concat(dfs, ignore_index=True)




# defining the target variable here 

# Calculate delivery duration (in minutes)
df_all['accept_time'] = pd.to_datetime(df_all['accept_time'])
df_all['delivery_time'] = pd.to_datetime(df_all['delivery_time'])

df_all['delivery_duration'] = (
    df_all['delivery_time'] - df_all['accept_time']
).dt.total_seconds() / 60  # minutes

y = df_all['delivery_duration'].values


## NEW FEATURES 

# Spatial features
# Distance between acceptance and delivery locations
df_all['travel_distance'] = np.sqrt(
    (df_all['delivery_gps_lng'] - df_all['acceptgpsx'])**2 + 
    (df_all['delivery_gps_lat'] - df_all['acceptgpsy'])**2
)

# Temporal features
df_all['accept_hour'] = df_all['accept_time'].dt.hour
df_all['accept_day_of_week'] = df_all['accept_time'].dt.dayofweek
df_all['is_rush_hour'] = df_all['accept_hour'].isin([7,8,9,17,18,19]).astype(int)
df_all['is_weekend'] = df_all['accept_day_of_week'].isin([5,6]).astype(int)

# AOI/Region features
from sklearn.preprocessing import LabelEncoder

le_aoi_type = LabelEncoder()
df_all['aoi_type_encoded'] = le_aoi_type.fit_transform(
    df_all['aoi_type'].fillna('unknown')
)

# Courier-level features (optional - experience/workload)
courier_stats = df_all.groupby('courier_id').agg({
    'delivery_duration': ['mean', 'count']
}).reset_index()
courier_stats.columns = ['courier_id', 'courier_avg_time', 'courier_n_deliveries']
df_all = df_all.merge(courier_stats, on='courier_id', how='left')

# Select features for X
feature_cols = [
    'travel_distance',
    'accept_hour',
    'accept_day_of_week',
    'is_rush_hour',
    'is_weekend',
    'aoi_type_encoded',
    # 'courier_avg_time',  # May cause leakage - use carefully
]

X = df_all[feature_cols].values
# Out:
# /tmp/ipykernel_5849/2900297473.py:27: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['accept_time'] = pd.to_datetime(df_all['accept_time'])
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File pandas/_libs/tslibs/conversion.pyx:326, in pandas._libs.tslibs.conversion._TSObject.ensure_reso()
#
# File pandas/_libs/tslibs/np_datetime.pyx:683, in pandas._libs.tslibs.np_datetime.convert_reso()
#
# OverflowError: result would overflow
#
# The above exception was the direct cause of the following exception:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[3], line 27
#      19 df_all = pd.concat(dfs, ignore_index=True)
#      24 # defining the target variable here
#      25
#      26 # Calculate delivery duration (in minutes)
# ---> 27 df_all['accept_time'] = pd.to_datetime(df_all['accept_time'])
#      28 df_all['delivery_time'] = pd.to_datetime(df_all['delivery_time'])
#      30 df_all['delivery_duration'] = (
#      31     df_all['delivery_time'] - df_all['accept_time']
#      32 ).dt.total_seconds() / 60  # minutes
#
# File ~/Documents/Github/starship/.venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/Documents/Github/starship/.venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:437, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     434 if format is not None and format != "mixed":
#     435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#     440     yearfirst=yearfirst,
#     441     utc=utc,
#     442     errors=errors,
#     443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#     449     out_unit = np.datetime_data(result.dtype)[0]
#
# File ~/Documents/Github/starship/.venv/lib/python3.12/site-packages/pandas/core/arrays/datetimes.py:2415, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2412 # if str-dtype, convert
#    2413 data = np.asarray(data, dtype=np.object_)
# -> 2415 result, tz_parsed = tslib.array_to_datetime(
#    2416     data,
#    2417     errors=errors,
#    2418     utc=utc,
#    2419     dayfirst=dayfirst,
#    2420     yearfirst=yearfirst,
#    2421     creso=abbrev_to_npy_unit(out_unit),
#    2422 )
#    2424 if tz_parsed is not None:
#    2425     # We can take a shortcut since the datetime64 numpy array
#    2426     #  is in UTC
#    2427     return result, tz_parsed
#
# File pandas/_libs/tslib.pyx:412, in pandas._libs.tslib.array_to_datetime()
#
# File pandas/_libs/tslib.pyx:596, in pandas._libs.tslib.array_to_datetime()
#
# File pandas/_libs/tslib.pyx:571, in pandas._libs.tslib.array_to_datetime()
#
# File pandas/_libs/tslibs/conversion.pyx:332, in pandas._libs.tslibs.conversion._TSObject.ensure_reso()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 10-22 10:26:00, at position 0

# %%
# environment indicators 

# 3 different cities = 3 environments
E = df_all['city'].values  # or 'city_code'

# Remove rows with missing values
mask = (
    ~np.isnan(y) & 
    ~np.any(np.isnan(X), axis=1) &
    (y > 0) & (y < 180)  # Remove outliers (e.g., >3 hours)
)

X_clean = X[mask]
y_clean = y[mask]
E_clean = E[mask]

print(f"Clean samples: {len(y_clean)}")
print(f"Unique environments: {len(np.unique(E_clean))}")

# %%
# Pseudo-code for ICP
from causal_library import InvariantCausalPrediction

icp = InvariantCausalPrediction(
    alpha=0.05,  # Significance level
    selection='all'  # Test all subsets or use greedy selection
)

# Fit ICP
causal_features = icp.fit(X_clean, y_clean, E_clean)

print("Causal feature indices:", causal_features)
print("Causal feature names:", [feature_cols[i] for i in causal_features])

# %% [markdown]
# # PC now
#
# -ICT gives 5-7 variables . now pc algorithm for verification

# %% [markdown]
# Step 1: Engineer causal features
# Step 2: Define environments e = (city, date)
# Step 3: Run ICP → get PA(Y)
# Step 4: Define Z = PA(Y)
# Step 5: (Optional) Run PC on Z ∪ {Y}
# Step 6: Feed Z into contextual bandit
